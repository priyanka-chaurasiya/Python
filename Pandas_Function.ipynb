# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka-chaurasiya/Python/blob/main/Pandas_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas function

# %% [markdown]
# | Function        | Easy Definition                    |
# | --------------- | ---------------------------------- |
# | `df.head()`     | Starting ki rows                   |
# | `df.tail()`     | Last ki rows                       |
# | `df.info()`     | Data ki complete basic information |
# | `df.describe()` | Numerical statistics               |
# | `df.shape`      | Rows aur columns ki number         |
# | `df.columns`    | Column names                       |
# | `df.index`      | Index information                  |
# | `df.dtypes`     | Data types                         |

# %% [markdown]
# Pandas Most Important Functions
#
#
# pd.Series()
#
# pd.DataFrame()
#
# pd.read_csv()
#
# df.to_csv()
#
# df.head()
#
# df.tail()
#
# df.info()
#
# df.describe()
#
# df.shape
#
# df.columns
#
# df.dtypes
#
# df.loc[]
#
# df.iloc[]
#
# df.insert()
#
# df.drop()
#
# df.isnull()
#
# df.dropna()
#
# df.fillna()
#
# df.duplicated()
#
# df.drop_duplicates()
#
# df.rename()
#
# df.replace()
#
# df.astype()
#
# df.sort_values()
#
# df.unique()
#
# df.nunique()
#
# df.value_counts()
#
# df.groupby()
#
# df.query()
#
# df.sum()
#
# df.mean()
#
# df.median()
#
# df.mode()
#
# df.min()
#
# df.max()
#
# df.count()
#
# df.std()
#
# df.var()
#
# pd.concat()
#
# pd.merge()
#
# df.join()

# %%
import pandas as pd

csv_1 = pd.read_csv("/content/Company_Employee_Data_Analysis.csv")
csv_1
# Out:
#     Employee_ID           Name  Age  Gender  Department  Experience_Years  \
# 0         10001   Aarav Sharma   25  Female          IT                11
# 1         10002   Priya Sharma   26    Male          HR                 4
# 2         10003   Rahul Sharma   35  Female     Finance                10
# 3         10004  Anjali Sharma   29    Male       Sales                 4
# 4         10005    Aman Sharma   28  Female   Marketing                 9
# ..          ...            ...  ...     ...         ...               ...
# 95        10096    Nisha Singh   28    Male  Operations                11
# 96        10097    Varun Singh   24  Female          IT                14
# 97        10098   Simran Singh   43    Male          HR                 7
# 98        10099   Deepak Singh   30  Female     Finance                 2
# 99        10100    Meena Singh   25    Male       Sales                 1
#
#     Salary    City  Performance_Score Joining_Date
# ...

# %%
csv_1.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
csv_1.columns
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Gender', 'Department',
#        'Experience_Years', 'Salary', 'City', 'Performance_Score',
#        'Joining_Date'],
#       dtype='object')

# %%
csv_1.describe()
# Out:
#         Employee_ID         Age  Experience_Years         Salary  \
# count    100.000000  100.000000        100.000000     100.000000
# mean   10050.500000   31.870000          7.110000   70795.700000
# std       29.011492    6.804121          4.167927   11535.048479
# min    10001.000000   22.000000          1.000000   51280.000000
# 25%    10025.750000   26.000000          4.000000   61411.750000
# 50%    10050.500000   30.000000          7.000000   70503.000000
# 75%    10075.250000   36.250000         11.000000   78691.000000
# max    10100.000000   45.000000         15.000000  103077.000000
#
#        Performance_Score
# count         100.000000
# mean            3.050000
# std             1.445124
# min             1.000000
# 25%             2.000000
# 50%             3.000000
# 75%             4.000000
# max             5.000000

# %%
csv_1.head()
# Out:
#    Employee_ID           Name  Age  Gender Department  Experience_Years  \
# 0        10001   Aarav Sharma   25  Female         IT                11
# 1        10002   Priya Sharma   26    Male         HR                 4
# 2        10003   Rahul Sharma   35  Female    Finance                10
# 3        10004  Anjali Sharma   29    Male      Sales                 4
# 4        10005    Aman Sharma   28  Female  Marketing                 9
#
#    Salary    City  Performance_Score Joining_Date
# 0   82061  Indore                  3   2017-06-29
# 1   56836  Bhopal                  5   2013-12-13
# 2   75650    Pune                  1   2014-02-06
# 3   65136  Mumbai                  5   2012-08-05
# 4   78694   Delhi                  5   2021-05-29

# %%
csv_1.head(4)
# Out:
#    Employee_ID           Name  Age  Gender Department  Experience_Years  \
# 0        10001   Aarav Sharma   25  Female         IT                11
# 1        10002   Priya Sharma   26    Male         HR                 4
# 2        10003   Rahul Sharma   35  Female    Finance                10
# 3        10004  Anjali Sharma   29    Male      Sales                 4
#
#    Salary    City  Performance_Score Joining_Date
# 0   82061  Indore                  3   2017-06-29
# 1   56836  Bhopal                  5   2013-12-13
# 2   75650    Pune                  1   2014-02-06
# 3   65136  Mumbai                  5   2012-08-05

# %%
csv_1.tail()
# Out:
#     Employee_ID          Name  Age  Gender  Department  Experience_Years  \
# 95        10096   Nisha Singh   28    Male  Operations                11
# 96        10097   Varun Singh   24  Female          IT                14
# 97        10098  Simran Singh   43    Male          HR                 7
# 98        10099  Deepak Singh   30  Female     Finance                 2
# 99        10100   Meena Singh   25    Male       Sales                 1
#
#     Salary    City  Performance_Score Joining_Date
# 95   73476  Jaipur                  3   2018-04-01
# 96   93994  Indore                  3   2023-06-05
# 97   68186  Bhopal                  3   2012-08-14
# 98   63730    Pune                  5   2017-12-14
# 99   57721  Mumbai                  4   2019-10-02

# %%
csv_1.tail(3)
# Out:
#     Employee_ID          Name  Age  Gender Department  Experience_Years  \
# 97        10098  Simran Singh   43    Male         HR                 7
# 98        10099  Deepak Singh   30  Female    Finance                 2
# 99        10100   Meena Singh   25    Male      Sales                 1
#
#     Salary    City  Performance_Score Joining_Date
# 97   68186  Bhopal                  3   2012-08-14
# 98   63730    Pune                  5   2017-12-14
# 99   57721  Mumbai                  4   2019-10-02

# %%
csv_1['Experience_Years']
# Out:
# 0     11
# 1      4
# 2     10
# 3      4
# 4      9
#       ..
# 95    11
# 96    14
# 97     7
# 98     2
# 99     1
# Name: Experience_Years, Length: 100, dtype: int64

# %%
csv_1[:2]
# Out:
#    Employee_ID          Name  Age  Gender Department  Experience_Years  \
# 0        10001  Aarav Sharma   25  Female         IT                11
# 1        10002  Priya Sharma   26    Male         HR                 4
#
#    Salary    City  Performance_Score Joining_Date
# 0   82061  Indore                  3   2017-06-29
# 1   56836  Bhopal                  5   2013-12-13

# %%
csv_1[6:11]
# Out:
#     Employee_ID          Name  Age  Gender Department  Experience_Years  \
# 6         10007  Rohit Sharma   27  Female         IT                13
# 7         10008  Sneha Sharma   26    Male         HR                 5
# 8         10009  Vikas Sharma   34  Female    Finance                 2
# 9         10010  Pooja Sharma   30    Male      Sales                10
# 10        10011  Arjun Sharma   34  Female  Marketing                 2
#
#     Salary       City  Performance_Score Joining_Date
# 6   103077  Hyderabad                  4   2019-08-19
# 7    59700     Jaipur                  3   2014-04-17
# 8    63396     Indore                  3   2019-09-18
# 9    70880     Bhopal                  4   2024-01-10
# 10   55322       Pune                  5   2018-07-29

# %%
print(type(csv_1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
csv_1.index.array
# Out:
# <NumpyExtensionArray>
# [ np.int64(0),  np.int64(1),  np.int64(2),  np.int64(3),  np.int64(4),
#   np.int64(5),  np.int64(6),  np.int64(7),  np.int64(8),  np.int64(9),
#  np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14),
#  np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19),
#  np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24),
#  np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29),
#  np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34),
#  np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39),
#  np.int64(40), np.int64(41), np.int64(42), np.int64(43), np.int64(44),
#  np.int64(45), np.int64(46), np.int64(47), np.int64(48), np.int64(49),
#  np.int64(50), np.int64(51), np.int64(52), np.int64(53), np.int64(54),
#  np.int64(55), np.int64(56), np.int64(57), np.int64(58), np.int64(59),
#  np.int64(60), np.int64(61), np.int64(62), np.int64(63), np.int64(64),
# ...

# %%
csv_1.to_numpy()
# Out:
# array([[10001, 'Aarav Sharma', 25, 'Female', 'IT', 11, 82061, 'Indore',
#         3, '2017-06-29'],
#        [10002, 'Priya Sharma', 26, 'Male', 'HR', 4, 56836, 'Bhopal', 5,
#         '2013-12-13'],
#        [10003, 'Rahul Sharma', 35, 'Female', 'Finance', 10, 75650,
#         'Pune', 1, '2014-02-06'],
#        [10004, 'Anjali Sharma', 29, 'Male', 'Sales', 4, 65136, 'Mumbai',
#         5, '2012-08-05'],
#        [10005, 'Aman Sharma', 28, 'Female', 'Marketing', 9, 78694,
#         'Delhi', 5, '2021-05-29'],
#        [10006, 'Neha Sharma', 36, 'Male', 'Operations', 4, 58824,
#         'Bengaluru', 3, '2012-02-23'],
#        [10007, 'Rohit Sharma', 27, 'Female', 'IT', 13, 103077,
#         'Hyderabad', 4, '2019-08-19'],
#        [10008, 'Sneha Sharma', 26, 'Male', 'HR', 5, 59700, 'Jaipur', 3,
#         '2014-04-17'],
#        [10009, 'Vikas Sharma', 34, 'Female', 'Finance', 2, 63396,
#         'Indore', 3, '2019-09-18'],
# ...

# %%
import numpy as np

v = np.array(csv_1)
v
# Out:
# array([[10001, 'Aarav Sharma', 25, 'Female', 'IT', 11, 82061, 'Indore',
#         3, '2017-06-29'],
#        [10002, 'Priya Sharma', 26, 'Male', 'HR', 4, 56836, 'Bhopal', 5,
#         '2013-12-13'],
#        [10003, 'Rahul Sharma', 35, 'Female', 'Finance', 10, 75650,
#         'Pune', 1, '2014-02-06'],
#        [10004, 'Anjali Sharma', 29, 'Male', 'Sales', 4, 65136, 'Mumbai',
#         5, '2012-08-05'],
#        [10005, 'Aman Sharma', 28, 'Female', 'Marketing', 9, 78694,
#         'Delhi', 5, '2021-05-29'],
#        [10006, 'Neha Sharma', 36, 'Male', 'Operations', 4, 58824,
#         'Bengaluru', 3, '2012-02-23'],
#        [10007, 'Rohit Sharma', 27, 'Female', 'IT', 13, 103077,
#         'Hyderabad', 4, '2019-08-19'],
#        [10008, 'Sneha Sharma', 26, 'Male', 'HR', 5, 59700, 'Jaipur', 3,
#         '2014-04-17'],
#        [10009, 'Vikas Sharma', 34, 'Female', 'Finance', 2, 63396,
#         'Indore', 3, '2019-09-18'],
# ...

# %%
csv_1.sort_index(axis=0, ascending=False)
# Out:
#     Employee_ID           Name  Age  Gender  Department  Experience_Years  \
# 99        10100    Meena Singh   25    Male       Sales                 1
# 98        10099   Deepak Singh   30  Female     Finance                 2
# 97        10098   Simran Singh   43    Male          HR                 7
# 96        10097    Varun Singh   24  Female          IT                14
# 95        10096    Nisha Singh   28    Male  Operations                11
# ..          ...            ...  ...     ...         ...               ...
# 4         10005    Aman Sharma   28  Female   Marketing                 9
# 3         10004  Anjali Sharma   29    Male       Sales                 4
# 2         10003   Rahul Sharma   35  Female     Finance                10
# 1         10002   Priya Sharma   26    Male          HR                 4
# 0         10001   Aarav Sharma   25  Female          IT                11
#
#     Salary    City  Performance_Score Joining_Date
# ...

# %%
csv_1['Department'][0] = 'python'
csv_1
# Out:
# /tmp/ipykernel_3989/3448181976.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   csv_1['Department'][0] = 'python'
# /tmp/ipykernel_3989/3448181976.py:1: SettingWithCopyWarning:
# ...

# %%
csv_1.loc[0,"Employee_Name"] = "python"
csv_1
# Out:
#     Employee_ID           Name  Age  Gender  Department  Experience_Years  \
# 0         10001   Aarav Sharma   25  Female      python                11
# 1         10002   Priya Sharma   26    Male          HR                 4
# 2         10003   Rahul Sharma   35  Female     Finance                10
# 3         10004  Anjali Sharma   29    Male       Sales                 4
# 4         10005    Aman Sharma   28  Female   Marketing                 9
# ..          ...            ...  ...     ...         ...               ...
# 95        10096    Nisha Singh   28    Male  Operations                11
# 96        10097    Varun Singh   24  Female          IT                14
# 97        10098   Simran Singh   43    Male          HR                 7
# 98        10099   Deepak Singh   30  Female     Finance                 2
# 99        10100    Meena Singh   25    Male       Sales                 1
#
#     Salary    City  Performance_Score Joining_Date Employee_Name
# ...

# %%
csv_1.loc[[2,3],["Name","Gender"]]
# Out:
#             Name  Gender
# 2   Rahul Sharma  Female
# 3  Anjali Sharma    Male

# %%
csv_1.loc[:,["Name","Gender"]]
# Out:
#              Name  Gender
# 0    Aarav Sharma  Female
# 1    Priya Sharma    Male
# 2    Rahul Sharma  Female
# 3   Anjali Sharma    Male
# 4     Aman Sharma  Female
# ..            ...     ...
# 95    Nisha Singh    Male
# 96    Varun Singh  Female
# 97   Simran Singh    Male
# 98   Deepak Singh  Female
# 99    Meena Singh    Male
#
# [100 rows x 2 columns]

# %%
csv_1.loc[2:3,:]
# Out:
#    Employee_ID           Name  Age  Gender Department  Experience_Years  \
# 2        10003   Rahul Sharma   35  Female    Finance                10
# 3        10004  Anjali Sharma   29    Male      Sales                 4
#
#    Salary    City  Performance_Score Joining_Date Employee_Name
# 2   75650    Pune                  1   2014-02-06           NaN
# 3   65136  Mumbai                  5   2012-08-05           NaN

# %%
csv_1.iloc[0,1]
# Out:
# 'Aarav Sharma'

# %%
csv_1.drop('Experience_Years',axis=1)
# Out:
#     Employee_ID           Name  Age  Gender  Department  Salary    City  \
# 0         10001   Aarav Sharma   25  Female      python   82061  Indore
# 1         10002   Priya Sharma   26    Male          HR   56836  Bhopal
# 2         10003   Rahul Sharma   35  Female     Finance   75650    Pune
# 3         10004  Anjali Sharma   29    Male       Sales   65136  Mumbai
# 4         10005    Aman Sharma   28  Female   Marketing   78694   Delhi
# ..          ...            ...  ...     ...         ...     ...     ...
# 95        10096    Nisha Singh   28    Male  Operations   73476  Jaipur
# 96        10097    Varun Singh   24  Female          IT   93994  Indore
# 97        10098   Simran Singh   43    Male          HR   68186  Bhopal
# 98        10099   Deepak Singh   30  Female     Finance   63730    Pune
# 99        10100    Meena Singh   25    Male       Sales   57721  Mumbai
#
#     Performance_Score Joining_Date Employee_Name
# 0                   3   2017-06-29        python
# ...

# %%
csv_1.drop(0,axis=0)
# Out:
#     Employee_ID           Name  Age  Gender  Department  Experience_Years  \
# 1         10002   Priya Sharma   26    Male          HR                 4
# 2         10003   Rahul Sharma   35  Female     Finance                10
# 3         10004  Anjali Sharma   29    Male       Sales                 4
# 4         10005    Aman Sharma   28  Female   Marketing                 9
# 5         10006    Neha Sharma   36    Male  Operations                 4
# ..          ...            ...  ...     ...         ...               ...
# 95        10096    Nisha Singh   28    Male  Operations                11
# 96        10097    Varun Singh   24  Female          IT                14
# 97        10098   Simran Singh   43    Male          HR                 7
# 98        10099   Deepak Singh   30  Female     Finance                 2
# 99        10100    Meena Singh   25    Male       Sales                 1
#
#     Salary       City  Performance_Score Joining_Date Employee_Name
# ...
