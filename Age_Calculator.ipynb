# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka-chaurasiya/Python/blob/main/Age_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Age Calculator

# %%
from datetime import date

# Take date of brith from user
day = int(input("Enter your day of birth: "))
month = int(input("Enter your month of birth: "))
year = int(input("Enter your year of birth: "))

# Current date
today = date.today()
current_day = today.day
current_month = today.month
current_year = today.year

# Current age
age = today.year - year

# Calculate age
age = today.year - year

# Check if birthday has occurred this year
if (today.month, today.day) < (month, day):
    age -= 1

print("Your age is:", age, "years")
# Out:
# Enter your day of birth: 15
# Enter your month of birth: 8
# Enter your year of birth: 2004
# Your age is: 22 years
