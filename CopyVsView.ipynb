# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka-chaurasiya/Python/blob/main/CopyVsView.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Copy Vs View

# %%
import numpy as np

var = np.array([1,2,3,4])

co = var.copy()

print("var : ",var)
print("copy : ",co)
# Out:
# var :  [1 2 3 4]
# copy :  [1 2 3 4]

# %%
x = np.array([9,8,7,6,5])

vi = x.view()

print("x : ",x)
print("view :",vi)
# Out:
# x :  [9 8 7 6 5]
# view : [9 8 7 6 5]

# %%
import numpy as np

var = np.array([1,2,3,4])

co = var.copy()

var[1]=40

print("var : ",var)
print("copy : ",co)
# Out:
# var :  [ 1 40  3  4]
# copy :  [1 2 3 4]

# %%
x = np.array([9,8,7,6,5])

vi = x.view()
x[1]=40

print("x : ",x)
print("view :",vi)
# Out:
# x :  [ 9 40  7  6  5]
# view : [ 9 40  7  6  5]
